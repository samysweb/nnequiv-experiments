# %%
import parse
import analyse
import matplotlib.pyplot as plt
import numpy as np

# %%
benchmarks = [
"../results/mnist8x8_100_200_300_200_100_10-9000.1-top",
"../results/mnist8x8_100_200_300_200_100_10-9000.3-top",
"../results/mnist8x8_100_200_300_200_100_10-9000.5-top",
"../results/mnist8x8_100_200_300_200_100_10-9100.1-top",
"../results/mnist8x8_100_200_300_200_100_10-9100.3-top",
"../results/mnist8x8_100_200_300_200_100_10-9100.5-top",
"../results/mnist8x8_100_200_300_200_100_10-9200.1-top",
"../results/mnist8x8_100_200_300_200_100_10-9200.3-top",
"../results/mnist8x8_100_200_300_200_100_10-9200.5-top",
"../results/mnist8x8_100_80_60_40_20_10-9000.1-top",
"../results/mnist8x8_100_80_60_40_20_10-9000.3-top",
"../results/mnist8x8_100_80_60_40_20_10-9000.5-top",
"../results/mnist8x8_100_80_60_40_20_10-9100.1-top",
"../results/mnist8x8_100_80_60_40_20_10-9100.3-top",
"../results/mnist8x8_100_80_60_40_20_10-9100.5-top",
"../results/mnist8x8_100_80_60_40_20_10-9200.1-top",
"../results/mnist8x8_100_80_60_40_20_10-9200.3-top",
"../results/mnist8x8_100_80_60_40_20_10-9200.5-top",
"../results/mnist8x8_student_12_12_12_10-9000.5-top",
"../results/mnist8x8_student_12_12_12_10-9003-top",
"../results/mnist8x8_student_12_12_12_10-9100.5-top",
"../results/mnist8x8_student_12_12_12_10-9103-top",
"../results/mnist8x8_student_24_12_10-9000.5-top",
"../results/mnist8x8_student_24_12_10-9003-top",
"../results/mnist8x8_student_24_12_10-9100.5-top",
"../results/mnist8x8_student_24_12_10-9103-top",
"../results/mnist8x8_student_36_10-9000.5-top",
"../results/mnist8x8_student_36_10-9003-top",
"../results/mnist8x8_student_36_10-9100.5-top",
"../results/mnist8x8_student_36_10-9103-top",
"../results/HAR-trunc-1000.1-0.25",
"../results/mnist_relu_3_100-trunc-400.1-0.25",
"../results/mnist784_36_10-400.001-top",
"../results/mnist784_36_10-400.01-top",
"../results/ACASXU_run2a_1_1_batch_2000-trunc-1010-0.05",
"../results/ACASXU_run2a_1_2_batch_2000-trunc-1010-0.05",
"../results/ACASXU_run2a_1_1_batch_2000-trunc-1-0.05",
"../results/ACASXU_run2a_1_2_batch_2000-trunc-1-0.05",
"../results/mnist8x8_student_12_12_12_10-9001-top",
"../results/mnist8x8_student_12_12_12_10-9101-top",
"../results/mnist8x8_student_24_12_10-9001-top",
"../results/mnist8x8_student_24_12_10-9101-top",
"../results/mnist8x8_student_36_10-9001-top",
"../results/mnist8x8_student_36_10-9101-top",
"../results/HAR-trunc-1000-0.25",
"../results/mnist_relu_3_100-trunc-400-0.25"
]
variants = [
    'DONT',
    'REFINE_UNTIL_LAST_OPTIMISTIC1',
    'REFINE_UNTIL_LAST',
    'REFINE_UNTIL_MAX'
]
commit = '02b650d'
out_handlers=[]
err_handlers=[parse.RunLim]
both_handlers=[parse.NNEquivResultHandler]

# %%
runs = []
for v in variants:
    cur_run = {}
    for b in benchmarks:
        try:
            cur_run[b]=parse.BenchmarkRun(
            b+"-"+v+"/"+"1/nnequiv-"+commit+"/stdout.log",
            b+"-"+v+"/"+"1/nnequiv-"+commit+"/stderr.log",
            out_handlers=out_handlers,
            err_handlers=err_handlers,
            both_handlers=both_handlers
            )
            print(f"Loaded {b}-{v}")
        except FileNotFoundError:
            print(f"Could not find {b}-{v}")
            cur_run[b]=None
    runs.append(cur_run)
# Out:
# Loaded ../results/mnist8x8_100_200_300_200_100_10-9000.1-top-DONT
# Loaded ../results/mnist8x8_100_200_300_200_100_10-9000.3-top-DONT
# Loaded ../results/mnist8x8_100_200_300_200_100_10-9000.5-top-DONT
# Loaded ../results/mnist8x8_100_200_300_200_100_10-9100.1-top-DONT
# Loaded ../results/mnist8x8_100_200_300_200_100_10-9100.3-top-DONT
# Loaded ../results/mnist8x8_100_200_300_200_100_10-9100.5-top-DONT
# Loaded ../results/mnist8x8_100_200_300_200_100_10-9200.1-top-DONT
# Loaded ../results/mnist8x8_100_200_300_200_100_10-9200.3-top-DONT
# Loaded ../results/mnist8x8_100_200_300_200_100_10-9200.5-top-DONT
# Loaded ../results/mnist8x8_100_80_60_40_20_10-9000.1-top-DONT
# Loaded ../results/mnist8x8_100_80_60_40_20_10-9000.3-top-DONT
# Loaded ../results/mnist8x8_100_80_60_40_20_10-9000.5-top-DONT
# Loaded ../results/mnist8x8_100_80_60_40_20_10-9100.1-top-DONT
# Loaded ../results/mnist8x8_100_80_60_40_20_10-9100.3-top-DONT
# Loaded ../results/mnist8x8_100_80_60_40_20_10-9100.5-top-DONT
# ...

# %%
buening_speedup = {}
buening_speedup_noop = {}
both_handlers=[parse.BueningResultHandler]
variants = [
    "", # Speedup with Bounds Optimization
    "noop" # Speedup without Bounds Optimization
]
for v in variants:
    cur_run = {}
    for b in benchmarks:
        try:
            cur_run[b]=parse.BenchmarkRun(
            b+"-"+v+"/"+"1/buening-0badb2c/stdout.log",
            b+"-"+v+"/"+"1/buening-0badb2c/stderr.log",
            out_handlers=out_handlers,
            err_handlers=err_handlers,
            both_handlers=both_handlers
            )
            print(f"Loaded {b}-{v}")
        except FileNotFoundError:
            print(f"Could not find {b}-{v}")
            cur_run[b]=None
    runs.append(cur_run)
# Out:
# Loaded ../results/mnist8x8_100_200_300_200_100_10-9000.1-top-
# Loaded ../results/mnist8x8_100_200_300_200_100_10-9000.3-top-
# Loaded ../results/mnist8x8_100_200_300_200_100_10-9000.5-top-
# Loaded ../results/mnist8x8_100_200_300_200_100_10-9100.1-top-
# Loaded ../results/mnist8x8_100_200_300_200_100_10-9100.3-top-
# Loaded ../results/mnist8x8_100_200_300_200_100_10-9100.5-top-
# Loaded ../results/mnist8x8_100_200_300_200_100_10-9200.1-top-
# Loaded ../results/mnist8x8_100_200_300_200_100_10-9200.3-top-
# Loaded ../results/mnist8x8_100_200_300_200_100_10-9200.5-top-
# Loaded ../results/mnist8x8_100_80_60_40_20_10-9000.1-top-
# Loaded ../results/mnist8x8_100_80_60_40_20_10-9000.3-top-
# Loaded ../results/mnist8x8_100_80_60_40_20_10-9000.5-top-
# Loaded ../results/mnist8x8_100_80_60_40_20_10-9100.1-top-
# Loaded ../results/mnist8x8_100_80_60_40_20_10-9100.3-top-
# Loaded ../results/mnist8x8_100_80_60_40_20_10-9100.5-top-
# Loaded ../results/mnist8x8_100_80_60_40_20_10-9200.1-top-
# ...

# %%
"""
'DONT',
    'REFINE_UNTIL_LAST_OPTIMISTIC1',
    'REFINE_UNTIL_LAST',
    'REFINE_UNTIL_MAX'
        "", # Speedup with Bounds Optimization
    "noop" # Speedup without Bounds Optimization
"""

comparison = analyse.ResultRunlimMultiComparator(runs,["exact", "last_opt1", "last", "max", "buening-speed", "buening-speed-noop"],benchmarks)
    
comparison.render_table("real")
# Out:
# Table for real
# <style  type="text/css" >
#     #T_3a475108_d4b8_11eb_89b8_5d580e8f7414row0_col5 {
#             font-weight:  bold;
#         }    #T_3a475108_d4b8_11eb_89b8_5d580e8f7414row1_col5 {
#             font-weight:  bold;
#         }    #T_3a475108_d4b8_11eb_89b8_5d580e8f7414row2_col3 {
#             font-weight:  bold;
#         }    #T_3a475108_d4b8_11eb_89b8_5d580e8f7414row3_col5 {
#             font-weight:  bold;
#         }    #T_3a475108_d4b8_11eb_89b8_5d580e8f7414row4_col5 {
#             font-weight:  bold;
#         }    #T_3a475108_d4b8_11eb_89b8_5d580e8f7414row5_col4 {
#             font-weight:  bold;
#         }    #T_3a475108_d4b8_11eb_89b8_5d580e8f7414row6_col4 {
#             font-weight:  bold;
#         }    #T_3a475108_d4b8_11eb_89b8_5d580e8f7414row7_col6 {
#             font-weight:  bold;
#         }    #T_3a475108_d4b8_11eb_89b8_5d580e8f7414row9_col4 {
#             font-weight:  bold;
# ...

# %%
data = comparison.get_data("real")
# nonequiv_data = data[data.Status=="not equiv"]
# nequiv_count=len(nonequiv_data)
# equiv_data = data[data.Status=="equiv"]
# equiv_count=len(nonequiv_data)
# fig, ax = plt.subplots(figsize=(8, 4))
# for i in range(2,nonequiv_data.shape[1]):
#     vals = []
#     for v in nonequiv_data.iloc[:,i]:
#         if isinstance(v,float):
#             vals.append(v)
#     #vals = [v for v in nonequiv_data[i] if instanceof(v,float)]
#     vals.sort()
#     n, bins, patches = plt.hist(vals, nequiv_count, histtype='step',cumulative=True, label=data.columns[i])
#     print(data.columns[i]+": "+str(n))
# ax.set_title('NEQUIV')
# ax.legend(loc='right')
# fig, ax = plt.subplots(figsize=(8, 4))
# for i in range(2,equiv_data.shape[1]):
#     vals = []
#     for v in equiv_data.iloc[:,i]:
#         if isinstance(v,float):
#             vals.append(v)
#     #vals = [v for v in nonequiv_data[i] if instanceof(v,float)]
#     vals.sort()
#     n, bins, patches = plt.hist(vals, equiv_count, histtype='step',cumulative=True, label=data.columns[i])
#     print(data.columns[i]+": "+str(n))
# ax.set_title('EQUIV')
# ax.legend(loc='right')
# plt.show()

# %% [markdown]
# It is not clear to me why buening claims that `../results/mnist8x8_student_36_10-9001-top` is not equivalent (the given output is not a counter-example of equivalence either)
# Float problem?
# ```
# Best objective 3.552713678801e-15, best bound 3.552713678801e-15, gap 0.0000%
# [RESULTS]
# [1.0, 1.0, 3.5, 13.5, 13.5, 2.5, 0.0, 0.0, 1.0, 0.5, 13.5, 10.5, 9.5, 12.5, 1.5, 1.0, 0.0, 5.5, 14.121386317710972, 2.5, 0.0, 10.5, 3.5, 0.0, 0.0, 6.5, 11.5, 0.0, 0.0, 6.5, 7.5, 1.0, 0.0, 5.5, 10.5, 0.0, 1.0, 5.5, 8.5, 0.0, 1.0, 3.4829271255554226, 12.5, 1.5, 1.0, 7.5, 6.5, 1.0, 1.0, 0.0, 11.5, 7.5, 7.5, 13.5, 2.5, 1.0, 1.0, 1.0, 3.5, 13.5, 14.5, 7.5, 1.0, 0.1542602784669012]
# 0.0
# [1.0, 1.0, 3.5, 13.5, 13.5, 2.5, 0.0, 0.0, 1.0, 0.5]
# +-----------------------------+------------------------------+
# |            NN 1             |             NN 2             |
# +=============================+==============================+
# | x_2_4 : -12.10698588308191  | x_1_4 : -17.298906749586326  |
# +-----------------------------+------------------------------+
# | x_2_1 : -4.480428200394291  | x_1_1 : -6.555067857214929   |
# +-----------------------------+------------------------------+
# | x_2_8 : -1.3223938288216897 | x_1_8 : -5.213867491076879   |
# +-----------------------------+------------------------------+
# | x_2_2 : 0.21219191209708588 | x_1_6 : -4.301936816202204   |
# +-----------------------------+------------------------------+
# | x_2_6 : 0.2596184803897465  | x_1_2 : -2.826793371627921   |
# +-----------------------------+------------------------------+
# | x_2_0 : 0.3677773513336016  | x_1_0 : -2.392873121719197   |
# +-----------------------------+------------------------------+
# | x_2_3 : 2.9771603915630585  | x_1_9 : -0.46285238037074633 |
# +-----------------------------+------------------------------+
# | x_2_9 : 3.1852825865143104  | x_1_3 : 3.7677390998424114   |
# +-----------------------------+------------------------------+
# | x_2_5 : 4.878264216472591   | x_1_5 : 4.048258785120286    |
# +-----------------------------+------------------------------+
# | x_2_7 : 7.61237624273515    | x_1_7 : 5.931992863806596    |
# +-----------------------------+------------------------------+
# ```

# %% [markdown]
# - We still need a comparison with smaller input dimensionality (PCA on MNIST8x8?)
# - We still need to rerun some benchmarks though I'm not very hopeful about the resulst there
# - Would it make sense to integrate Gurobi into GPE approach? After all we are also comparing two different LP solvers right now...
