# %%
import parse
import analyse
import matplotlib.pyplot as plt
import numpy as np

# %%
benchmarks = [
"results/ACASXU_run2a_1_1_batch_2000-retrain-1-0.05",
"results/ACASXU_run2a_1_1_batch_2000-student-1-0.05",
"results/ACASXU_run2a_1_2_batch_2000-retrain-1-0.05",
"results/ACASXU_run2a_1_2_batch_2000-student-1-0.05",
"results/mnist8x8_100_80_60_40_20_10_eps1-9000.2-15",
"results/mnist8x8_student_36_10-9000.7-top",
"results/mnist8x8_student_12_12_12_10-9000.7-top",
"results/mnist8x8_100_80_60_40_20_10-9200.3-top",
"results/mnist8x8_100_200_300_200_100_10-9200.2-top"
]
variants = [
    'REFINE_UNTIL_LAST_OPTIMISTIC1',
    'DONT'
]
commit = '3ad4254' # lp solving
out_handlers=[parse.CegarOptimal]
err_handlers=[parse.RunLim]
both_handlers=[parse.NNEquivResultHandler]
num_runs=1

# %%
variant_runs = {}
for v in variants:
    variant_runs[v]={}
    for b in benchmarks:
        variant_runs[v][b]=[]
        for i in range(1,num_runs+1):
            try:
                variant_runs[v][b].append(
                    parse.BenchmarkRun(
                        "../"+b+"-"+v+"/"+str(i)+"/nnequiv-"+commit+"/stdout.log",
                        "../"+b+"-"+v+"/"+str(i)+"/nnequiv-"+commit+"/stderr.log",
                        out_handlers=out_handlers,
                        err_handlers=err_handlers,
                        both_handlers=both_handlers
                    )
                )
            except FileNotFoundError:
                print(f"Count not find "+b+"-"+v+"/"+str(i)+"/nnequiv-"+commit+"/stdout.log")

# %%
variants = [
    '',
    'noop'
]
commit = '04f3bfb'
out_handlers=[]
err_handlers=[parse.RunLim]
both_handlers=[parse.BueningResultHandler]
num_runs=3

# %%
for v in variants:
    variant_runs[v]={}
    for b in benchmarks:
        variant_runs[v][b]=[]
        for i in range(1,num_runs+1):
            try:
                variant_runs[v][b].append(
                    parse.BenchmarkRun(
                        "../"+b+"-"+v+"/"+str(i)+"/buening-"+commit+"/stdout.log",
                        "../"+b+"-"+v+"/"+str(i)+"/buening-"+commit+"/stderr.log",
                        out_handlers=out_handlers,
                        err_handlers=err_handlers,
                        both_handlers=both_handlers
                    )
                )
            except FileNotFoundError:
                print(f"Count not find "+b+"-"+v+"/"+str(i)+"/buening-"+commit+"/stdout.log")

# %%
variants = [
    'REFINE_UNTIL_LAST_OPTIMISTIC1',
    'DONT'
]
benchmarks = [
"results/ACASXU_run2a_1_1_batch_2000-retrain-1-0.05",
"results/ACASXU_run2a_1_1_batch_2000-student-1-0.05",
"results/ACASXU_run2a_1_2_batch_2000-retrain-1-0.05",
"results/ACASXU_run2a_1_2_batch_2000-student-1-0.05",
"results/mnist8x8_100_80_60_40_20_10_eps1-9000.2-15",
"results/mnist8x8_student_36_10-9000.7-top",
"results/mnist8x8_student_12_12_12_10-9000.7-top",
"results/mnist8x8_100_80_60_40_20_10-9200.3-top",
"results/mnist8x8_100_200_300_200_100_10-9200.2-top"
]
commit = 'fe93551'
out_handlers=[]
err_handlers=[parse.RunLim]
both_handlers=[parse.NNEquivResultHandler]
num_runs=1

# %%
benchmarks_savedas = [
"results/ACASXU_run2a_1_1_batch_2000-retrain-1-0.05",
"results/ACASXU_run2a_1_1_batch_2000-student-1-0.05",
"results/ACASXU_run2a_1_2_batch_2000-retrain-1-0.05",
"results/ACASXU_run2a_1_2_batch_2000-student-1-0.05",
"results/mnist8x8_100_80_60_40_20_10_eps1-9000.2-15",
"results/mnist8x8_student_36_10-9000.7-top",
"results/mnist8x8_student_12_12_12_10-9000.7-top",
"results/mnist8x8_100_80_60_40_20_10-9200.3-top",
"results/mnist8x8_100_200_300_200_100_10-9200.2-top"
]
for v in variants:
    variant_runs[v+"-gurobi"]={}
    for b, bsave in zip(benchmarks, benchmarks_savedas):
        variant_runs[v+"-gurobi"][bsave]=[]
        for i in range(1,num_runs+1):
            try:
                variant_runs[v+"-gurobi"][bsave].append(
                    parse.BenchmarkRun(
                        "../"+b+"-"+v+"/"+str(i)+"/nnequiv-"+commit+"/stdout.log",
                        "../"+b+"-"+v+"/"+str(i)+"/nnequiv-"+commit+"/stderr.log",
                        out_handlers=out_handlers,
                        err_handlers=err_handlers,
                        both_handlers=both_handlers
                    )
                )
            except FileNotFoundError:
                print(f"Count not find "+b+"-"+v+"/"+str(i)+"/buening-"+commit+"/stdout.log")

# %%
benchmarks = [
"results/ACASXU_run2a_1_1_batch_2000-retrain-1-0.05",
"results/ACASXU_run2a_1_1_batch_2000-student-1-0.05",
"results/ACASXU_run2a_1_2_batch_2000-retrain-1-0.05",
"results/ACASXU_run2a_1_2_batch_2000-student-1-0.05",
"results/mnist8x8_100_80_60_40_20_10_eps1-9000.2-15",
"results/mnist8x8_student_36_10-9000.7-top",
"results/mnist8x8_student_12_12_12_10-9000.7-top",
"results/mnist8x8_100_80_60_40_20_10-9200.3-top",
"results/mnist8x8_100_200_300_200_100_10-9200.2-top"
]
variants = [
    'DONT',
    'REFINE_UNTIL_LAST_OPTIMISTIC1',
    'DONT-gurobi',
    'REFINE_UNTIL_LAST_OPTIMISTIC1-gurobi',
    '',
    'noop'
]
variants_median = {}
for v in variants:
    variants_median[v]={}
    for b in benchmarks:
        variants_median[v][b]=parse.AggregateRun(variant_runs[v][b])

print(variants_median["REFINE_UNTIL_LAST_OPTIMISTIC1"]["results/ACASXU_run2a_1_1_batch_2000-retrain-1-0.05"].get_val(['runlim','real']))
print(variants_median[""]["results/ACASXU_run2a_1_1_batch_2000-retrain-1-0.05"].get_val(['runlim','real']))
print(variants_median["noop"]["results/ACASXU_run2a_1_1_batch_2000-retrain-1-0.05"].get_val(['runlim','real']))
# Out:
# 167.45
# 10800.1
# 10800.17

# %%
import pandas as pd

# %%
benchmarks_labels = {
"results/ACASXU_run2a_1_1_batch_2000-retrain-1-0.05":"ACAS_1_1-retrain",
"results/ACASXU_run2a_1_1_batch_2000-student-1-0.05":"ACAS_1_1-student",
"results/ACASXU_run2a_1_2_batch_2000-retrain-1-0.05":"ACAS_1_2-retrain",
"results/ACASXU_run2a_1_2_batch_2000-student-1-0.05":"ACAS_1_2-student",
"results/mnist8x8_100_80_60_40_20_10_eps1-9000.2-15":"MNIST_large-epsilon",
"results/mnist8x8_student_36_10-9000.7-top":"MNIST_small-top",
"results/mnist8x8_student_12_12_12_10-9000.7-top":"MNIST_medium-top",
"results/mnist8x8_100_80_60_40_20_10-9200.3-top":"MNIST_large-top",
"results/mnist8x8_100_200_300_200_100_10-9200.2-top":"MNIST_larger-top"
}

columns = ["Name", "Status", "Equiv", "LPNNEquiv (Exact)", "LPNNEquiv (Last)", "OLPNNEquiv (Exact)", "OLPNNEquiv (Last)", "Kleine Büning", "Kleine Büning (noop)"]
data = []
for b in benchmarks:
    cur_row = []
    cur_row.append(benchmarks_labels[b])
    cur_row.append("")
    cur_row.append("")
    for v in variants:
        cur_row[1]+="/"+str(variants_median[v][b].get_val(['result','status'],strategy='A')[0])
        cur_row[2]+="/"+str(variants_median[v][b].get_val(['result','is_equiv'],strategy='A')[0])
        cur_row.append(variants_median[v][b].get_val(['runlim','real']))
    data.append(cur_row)
print(columns)
table = pd.DataFrame(data, columns=columns)
table
# Out:
# ['Name', 'Status', 'Equiv', 'LPNNEquiv (Exact)', 'LPNNEquiv (Last)', 'OLPNNEquiv (Exact)', 'OLPNNEquiv (Last)', 'Kleine Büning', 'Kleine Büning (noop)']
#                   Name                 Status  \
# 0     ACAS_1_1-retrain   /ok/ok/ok/ok/out/out
# 1     ACAS_1_1-student   /ok/ok/ok/ok/out/out
# 2     ACAS_1_2-retrain   /ok/ok/ok/ok/out/out
# 3     ACAS_1_2-student    /ok/ok/ok/ok/ok/out
# 4  MNIST_large-epsilon    /out/ok/ok/ok/ok/ok
# 5      MNIST_small-top     /ok/ok/ok/ok/ok/ok
# 6     MNIST_medium-top     /ok/ok/ok/ok/ok/ok
# 7      MNIST_large-top   /out/ok/out/ok/ok/ok
# 8     MNIST_larger-top  /out/ok/out/ok/ok/out
#
#                               Equiv  LPNNEquiv (Exact)  LPNNEquiv (Last)  \
# 0    /True/True/True/True/True/True            2777.24            167.45
# 1    /True/True/True/True/True/True            4473.33             74.52
# 2    /True/True/True/True/True/True            4518.90            315.13
# 3   /True/True/True/True/False/True            2009.24            105.18
# 4  /True/True/True/True/False/False           10800.03             33.43
# 5    /True/True/True/True/True/True            7381.34             14.39
# 6    /True/True/True/True/True/True             969.58             96.41
# 7    /True/True/True/True/True/True           10800.08             11.41
# 8    /True/True/True/True/True/True           10800.06            715.87
#
#    OLPNNEquiv (Exact)  OLPNNEquiv (Last)  Kleine Büning  Kleine Büning (noop)
# 0             4592.77             174.68       10800.10              10800.17
# 1             7932.36              80.29       10800.12              10800.13
# 2             8428.20             330.45            NaN              10800.13
# 3             3360.98             110.32         320.07              10800.06
# 4             7810.79              30.30          19.97                114.09
# 5             7032.94              13.09           3.51                  2.79
# 6              949.12              87.86           3.85                  2.87
# 7            10800.10              11.69          25.85                 11.47
# 8            10800.11             659.61         386.04              10800.06

# %%
benchmarks_labels = {
"results/ACASXU_run2a_1_1_batch_2000-retrain-1-0.05":"ACAS_1_1-retrain",
"results/ACASXU_run2a_1_1_batch_2000-student-1-0.05":"ACAS_1_1-student",
"results/ACASXU_run2a_1_2_batch_2000-retrain-1-0.05":"ACAS_1_2-retrain",
"results/ACASXU_run2a_1_2_batch_2000-student-1-0.05":"ACAS_1_2-student",
"results/mnist8x8_100_80_60_40_20_10_eps1-9000.2-15":"MNIST_large-epsilon",
"results/mnist8x8_student_36_10-9000.7-top":"MNIST_small-top",
"results/mnist8x8_student_12_12_12_10-9000.7-top":"MNIST_medium-top",
"results/mnist8x8_100_80_60_40_20_10-9200.3-top":"MNIST_large-top",
"results/mnist8x8_100_200_300_200_100_10-9200.2-top":"MNIST_larger-top"
}

columns = ["Name", "Status", "Equiv", "LPNNEquiv (Exact)", "LPNNEquiv (Last)", "OLPNNEquiv (Exact)", "OLPNNEquiv (Last)", "Kleine Büning", "Kleine Büning (noop)"]
data = []
for b in benchmarks:
    cur_row = []
    cur_row.append(benchmarks_labels[b])
    cur_row.append("")
    cur_row.append("")
    for v in variants:
        cur_row[1]+="/"+str(variants_median[v][b].get_val(['result','status'],strategy='A')[0])
        cur_row[2]+="/"+str(variants_median[v][b].get_val(['result','is_equiv'],strategy='A')[0])
        cur_row.append(variants_median[v][b].get_val(['runlim','space']))
    data.append(cur_row)
print(columns)
table = pd.DataFrame(data, columns=columns)
table
# Out:
# ['Name', 'Status', 'Equiv', 'LPNNEquiv (Exact)', 'LPNNEquiv (Last)', 'OLPNNEquiv (Exact)', 'OLPNNEquiv (Last)', 'Kleine Büning', 'Kleine Büning (noop)']
#                   Name                 Status  \
# 0     ACAS_1_1-retrain   /ok/ok/ok/ok/out/out
# 1     ACAS_1_1-student   /ok/ok/ok/ok/out/out
# 2     ACAS_1_2-retrain   /ok/ok/ok/ok/out/out
# 3     ACAS_1_2-student    /ok/ok/ok/ok/ok/out
# 4  MNIST_large-epsilon    /out/ok/ok/ok/ok/ok
# 5      MNIST_small-top     /ok/ok/ok/ok/ok/ok
# 6     MNIST_medium-top     /ok/ok/ok/ok/ok/ok
# 7      MNIST_large-top   /out/ok/out/ok/ok/ok
# 8     MNIST_larger-top  /out/ok/out/ok/ok/out
#
#                               Equiv  LPNNEquiv (Exact)  LPNNEquiv (Last)  \
# 0    /True/True/True/True/True/True               95.2              96.6
# 1    /True/True/True/True/True/True               95.4              96.3
# 2    /True/True/True/True/True/True               95.4              98.0
# 3   /True/True/True/True/False/True               95.5              97.6
# 4  /True/True/True/True/False/False               98.4              97.1
# 5    /True/True/True/True/True/True               97.3              96.7
# 6    /True/True/True/True/True/True               96.5              97.2
# 7    /True/True/True/True/True/True               99.8             105.1
# 8    /True/True/True/True/True/True              104.2             102.7
#
#    OLPNNEquiv (Exact)  OLPNNEquiv (Last)  Kleine Büning  Kleine Büning (noop)
# 0                95.8               96.6          483.2                 764.5
# 1                96.0               96.3          396.4                 457.2
# 2                96.3               98.1            NaN                 620.9
# 3                95.8               97.4          190.4                 290.2
# 4                98.9               96.8          131.9                 213.6
# 5                97.3               96.1          103.4                  98.3
# 6                96.5               97.2          102.5                  97.4
# 7               100.0               98.3          135.0                 129.5
# 8               108.0              102.4          516.3                 401.7
