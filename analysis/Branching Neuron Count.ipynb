            err_handlers=[],
            both_handlers=[]
            )

# %%
len(acas_exact.split.split_positions.keys())
# Out:
# 241

# %%
overapprox_hash = {}
for s in all_overapprox_splits:
    overapprox_hash[s]=1

# %%
def get_split_plot(split_hash):
    net1 = {}
    net2 = {}
    for s in split_hash.keys():
        if s[0]==0:
            if s[1] in net1:
                net1[s[1]]+=1
            else:
                net1[s[1]]=1
        elif s[0]==1:
            if s[1] in net2:
                net2[s[1]]+=1
            else:
                net2[s[1]]=1
    return net1, net2
cegar_net1, cegar_net2 = get_split_plot(overapprox_hash)
exact_net1, exact_net2 = get_split_plot(acas_exact.split.split_positions)

# %%
def get_split_share(splits,net):
    rv = []
    for layer in net.keys():
        rv.append(splits[layer]/net[layer])
    return rv
cegar_net1_share = get_split_share(cegar_net1, net1_arch)
cegar_net2_share = get_split_share(cegar_net2, net2_arch)
exact_net1_share = get_split_share(exact_net1, net1_arch)
exact_net2_share = get_split_share(exact_net2, net2_arch)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from cycler import cycler
dot_cycle = (cycler('marker', ['|','x','.'])*cycler('linestyle', ['-',':']))
styles = dot_cycle()

# %%
x = [1,2,3,4,5,6]
fig= plt.figure(figsize=(2, 3.5))
axes= fig.add_axes([1,0.1,6,1.0])
axes.plot(x, cegar_net1_share, label="Overapprox Net1", color='black', **next(styles))
axes.plot(x, cegar_net2_share, label="Overapprox Net2", color='black', **next(styles))
axes.plot(x, exact_net1_share, label="Exact Net1 (overall)", color='black', **next(styles))
axes.plot(x, exact_net2_share, label="Exact Net2 (overall)", color='black', **next(styles))
#axes.set_title("Share of split neurons per layer",fontsize=22)
axes.set_xlabel("Layer in Network",fontsize=22)
axes.set_ylabel("Share of split neurons",fontsize=22)
axes.legend(fontsize=20)

# %%
split_hash=acas_exact.split.split_positions
split_pos_count = [0]*(50*12)
keys = split_hash.keys()
for s in keys:
    pos = (50*6)*s[0]+50*(s[1]//3)+s[2]
    split_pos_count[pos]+=split_hash[s]
fig= plt.figure(figsize=(10, 30))
axes= fig.add_subplot(511)
x = np.arange(0, len(split_pos_count), 1)
axes.bar(x, split_pos_count)
# Out:
# <BarContainer object of 600 artists>

# %%
fig, axs = plt.subplots(1, 1, sharey=True, tight_layout=True)
data = split_pos_count
max_val = max(data)
min_val = min(data)
n_bins = max_val-min_val+1

# We can set the number of bins with the `bins` kwarg
axs.hist(data, bins=n_bins)
axs.set_title("distribution of split usage")
# Out:
# Text(0.5, 1.0, 'distribution of split usage')

# %%
cegar_all_overapprox = [(50, 11, 0), (50, 21, 0), (50, 50, 0), (50, 50, 0), (50, 50, 0), (50, 50, 0), (50, 11, 0), (50, 21, 0), (50, 50, 0), (50, 50, 0), (50, 50, 0), (50, 50, 0)]

# %%
exemplary_exact = [(50, 5, 5), (50, 3, 0), (50, 8, 5), (50, 3, 2), (50, 4, 4), (50, 1, 1), (50, 1, 0), (50, 0, 0), (50, 4, 3), (50, 2, 2), (50, 2, 1), (50, 1, 1)]
