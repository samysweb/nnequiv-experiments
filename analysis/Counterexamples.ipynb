top-",
"mnist8x8_100_80_60_40_20_10-vmnist_large_97-top-",
"mnist8x8_100_80_60_40_20_10-vmnist_large_98-top-",
"mnist8x8_100_80_60_40_20_10-vmnist_large_99-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_0-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_1-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_2-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_3-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_4-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_5-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_6-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_7-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_8-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_9-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_10-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_11-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_12-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_13-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_14-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_15-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_16-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_17-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_18-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_19-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_20-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_21-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_22-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_23-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_24-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_25-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_26-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_27-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_28-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_29-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_30-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_31-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_32-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_33-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_34-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_35-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_36-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_37-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_38-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_39-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_40-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_41-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_42-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_43-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_44-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_45-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_46-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_47-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_48-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_49-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_50-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_51-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_52-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_53-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_54-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_55-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_56-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_57-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_58-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_59-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_60-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_61-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_62-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_63-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_64-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_65-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_66-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_67-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_68-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_69-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_70-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_71-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_72-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_73-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_74-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_75-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_76-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_77-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_78-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_79-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_80-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_81-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_82-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_83-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_84-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_85-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_86-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_87-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_88-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_89-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_90-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_91-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_92-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_93-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_94-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_95-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_96-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_97-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_98-top-",
"mnist8x8_100_200_300_200_100_10-vmnist_larger_99-top-"]
variants = [
    'REFINE_UNTIL_LAST_OPTIMISTIC1'
]
commit = '06a2d52'
out_handlers=[]
err_handlers=[parse.RunLim]
both_handlers=[parse.NNEquivResultHandler]
num_runs=3

# %%
variant_runs = {}
for v in variants:
    variant_runs[v]={}
    for b in benchmarks:
        variant_runs[v][b]=[]
        for i in range(1,num_runs+1):
            try:
                variant_runs[v][b].append(
                    parse.BenchmarkRun(
                        "../results-counter/"+b+v+"/"+str(i)+"/nnequiv-"+commit+"/stdout.log",
                        "../results-counter/"+b+v+"/"+str(i)+"/nnequiv-"+commit+"/stderr.log",
                        out_handlers=out_handlers,
                        err_handlers=err_handlers,
                        both_handlers=both_handlers
                    )
                )
            except (FileNotFoundError, Exception):
                print(f"Count not find ../results-counter/"+b+v+"/"+str(i)+"/nnequiv-"+commit+"/stdout.log")

# %%
variants = [
    'REFINE_UNTIL_LAST_OPTIMISTIC1',
]
variants_median = {}
for v in variants:
    variants_median[v]={}
    for b in benchmarks:
        variants_median[v][b]=parse.AggregateRun(variant_runs[v][b])

print(variants_median["REFINE_UNTIL_LAST_OPTIMISTIC1"]["mnist8x8_100_200_300_200_100_10-vmnist_larger_99-top-"].get_val(['runlim','real']))
# Out:
# 1.99

# %%
variants = [
    ('noop','04f3bfb'),
    ('','c442708')
]
out_handlers=[]
err_handlers=[parse.RunLim]
both_handlers=[parse.BueningResultHandler]
num_runs=3

# %%
for v, commit in variants:
    variant_runs[v]={}
    for b in benchmarks:
        variant_runs[v][b]=[]
        for i in range(1,num_runs+1):
            try:
                variant_runs[v][b].append(
                    parse.BenchmarkRun(
                        "../results-counter/"+b+v+"/"+str(i)+"/buening-"+commit+"/stdout.log",
                        "../results-counter/"+b+v+"/"+str(i)+"/buening-"+commit+"/stderr.log",
                        out_handlers=out_handlers,
                        err_handlers=err_handlers,
                        both_handlers=both_handlers
                    )
                )
            except (FileNotFoundError, Exception):
                print(f"Count not find ../results-counter/"+b+v+"/"+str(i)+"/buening-"+commit+"/stdout.log")
# Out:
# Count not find ../results-counter/ACASXU_run2a_1_2_batch_2000-student-vACAS_12_student_22-0.05-/1/buening-c442708/stdout.log
# Count not find ../results-counter/ACASXU_run2a_1_2_batch_2000-student-vACAS_12_student_22-0.05-/2/buening-c442708/stdout.log
# Count not find ../results-counter/ACASXU_run2a_1_2_batch_2000-student-vACAS_12_student_22-0.05-/3/buening-c442708/stdout.log
# Count not find ../results-counter/mnist8x8_student_36_10-vmnist_small_41-top-/1/buening-c442708/stdout.log
# Count not find ../results-counter/mnist8x8_student_36_10-vmnist_small_41-top-/2/buening-c442708/stdout.log
# Count not find ../results-counter/mnist8x8_student_36_10-vmnist_small_41-top-/3/buening-c442708/stdout.log
# Count not find ../results-counter/mnist8x8_100_80_60_40_20_10-vmnist_large_94-top-/1/buening-c442708/stdout.log
# Count not find ../results-counter/mnist8x8_100_80_60_40_20_10-vmnist_large_94-top-/2/buening-c442708/stdout.log
# ...

# %%
for v,_ in variants:
    variants_median[v]={}
    for b in benchmarks:
        variants_median[v][b]=parse.AggregateRun(variant_runs[v][b])

print(variants_median[""]["mnist8x8_100_200_300_200_100_10-vmnist_larger_99-top-"].get_val(['runlim','real']))
# Out:
# 120.1

# %%
variants_median[""]["ACASXU_run2a_1_2_batch_2000-student-vACAS_12_student_22-0.05-"].get_val(['runlim','status'],strategy='A')
# Out:
# []

# %%
variants = [
    "REFINE_UNTIL_LAST_OPTIMISTIC1",
    "noop",
    ""
]
aggtime = {v:0.0 for v in variants}
aggsolved = {v:0 for v in variants}
aggtimeto = {v:0 for v in variants}

for v in variants:
    for b in benchmarks:
        runs = variants_median[v][b].get_val(['runlim','status'],strategy='A')
        if None in runs or len(runs)!=3:
            print(f"Missed {v} {b}")
            aggsolved[v]+=1
            continue
        if 'out' in runs and 'ok' in runs:
            print(f"Ambiuous{v} {b}")
        if 'ok' in runs:
            aggsolved[v]+=1
            aggtime[v]+=variants_median[v][b].get_val(['runlim','real'],strategy='M')
        aggtimeto[v]+=variants_median[v][b].get_val(['runlim','real'],strategy='M')
print(aggsolved)
print(aggtime)
        #if runs is None:
        #    print(f"Could not find {v} {v}")
        #    aggsolved[v]+=1
        #.get_val(['runlim','real'])
print(aggtimeto)
for v in variants:
    print(v)
    print(aggtime[v]/aggsolved[v])
# Out:
# Missed  ACASXU_run2a_1_2_batch_2000-student-vACAS_12_student_22-0.05-
# Missed  mnist8x8_student_36_10-vmnist_small_41-top-
# Missed  mnist8x8_100_80_60_40_20_10-vmnist_large_94-top-
# {'REFINE_UNTIL_LAST_OPTIMISTIC1': 890, 'noop': 315, '': 305}
# {'REFINE_UNTIL_LAST_OPTIMISTIC1': 2396.2700000000004, 'noop': 2271.8899999999976, '': 4547.619999999999}
# {'REFINE_UNTIL_LAST_OPTIMISTIC1': 3597.1000000000035, 'noop': 72515.61, '': 75989.94000000005}
# REFINE_UNTIL_LAST_OPTIMISTIC1
# 2.6924382022471915
# noop
# 7.212349206349199
#
# 14.910229508196718
